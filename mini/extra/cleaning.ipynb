# %%
import pandas as pd

# %%
car = pd.read_csv('train-data.csv')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         6019 non-null   int64
#  1   Name               6019 non-null   object
#  2   Location           6019 non-null   object
#  3   Year               6019 non-null   int64
#  4   Kilometers_Driven  6019 non-null   int64
#  5   Fuel_Type          6019 non-null   object
#  6   Transmission       6019 non-null   object
#  7   Owner_Type         6019 non-null   object
#  8   Mileage            6017 non-null   object
#  9   Engine             5983 non-null   object
#  10  Power              5983 non-null   object
#  11  Seats              5977 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 658.5+ KB

# %%
car.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# ...

# %%
backup=car.copy()

# %%
car = car[~car['Seats'].isna()]

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
car.drop(["Owner_Type","Mileage","Engine","Power","New_Price"], inplace = True, axis=1)

# %%
car
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission  Seats  Price
# 0                 72000       CNG       Manual    5.0   1.75
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5977 entries, 0 to 6018
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5977 non-null   int64
#  1   Name               5977 non-null   object
#  2   Location           5977 non-null   object
#  3   Year               5977 non-null   int64
#  4   Kilometers_Driven  5977 non-null   int64
#  5   Fuel_Type          5977 non-null   object
#  6   Transmission       5977 non-null   object
#  7   Seats              5977 non-null   float64
#  8   Price              5977 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 596.0+ KB

# %%
car1=car['Name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car1=car['Name'].str.split(' ').str.slice(0,1).str.join(' ')

# %%
car1
# Out:
# 0          Maruti
# 1         Hyundai
# 2           Honda
# 3          Maruti
# 4            Audi
#           ...
# 6014       Maruti
# 6015      Hyundai
# 6016     Mahindra
# 6017       Maruti
# 6018    Chevrolet
# Name: Name, Length: 5977, dtype: object

# %%
company = car1

# %%
company
# Out:
# 0          Maruti
# 1         Hyundai
# 2           Honda
# 3          Maruti
# 4            Audi
#           ...
# 6014       Maruti
# 6015      Hyundai
# 6016     Mahindra
# 6017       Maruti
# 6018    Chevrolet
# Name: Name, Length: 5977, dtype: object

# %%
c=car

# %%
c=c.merge(company, left_index = True, right_index = True)

# %%
c.head()
# Out:
#    Unnamed: 0                            Name_x    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission  Seats  Price   Name_y
# 0              72000       CNG       Manual    5.0   1.75   Maruti
# 1              41000    Diesel       Manual    5.0  12.50  Hyundai
# 2              46000    Petrol       Manual    5.0   4.50    Honda
# 3              87000    Diesel       Manual    7.0   6.00   Maruti
# 4              40670    Diesel    Automatic    5.0  17.74     Audi

# %%
c = c.rename(columns = {"Name_x": "Model",
                                  "Name_y":"Company"})

# %%
c.head()
# Out:
#    Unnamed: 0                             Model    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission  Seats  Price  Company
# 0              72000       CNG       Manual    5.0   1.75   Maruti
# 1              41000    Diesel       Manual    5.0  12.50  Hyundai
# 2              46000    Petrol       Manual    5.0   4.50    Honda
# 3              87000    Diesel       Manual    7.0   6.00   Maruti
# 4              40670    Diesel    Automatic    5.0  17.74     Audi

# %%
c=c.reset_index(drop=True)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5977 entries, 0 to 5976
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5977 non-null   int64
#  1   Model              5977 non-null   object
#  2   Location           5977 non-null   object
#  3   Year               5977 non-null   int64
#  4   Kilometers_Driven  5977 non-null   int64
#  5   Fuel_Type          5977 non-null   object
#  6   Transmission       5977 non-null   object
#  7   Seats              5977 non-null   float64
#  8   Price              5977 non-null   float64
#  9   Company            5977 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 467.1+ KB

# %%
c1=c

# %%
c1.drop(c1.columns[0], axis=1, inplace=True)

# %%
c1.head()
# Out:
#                               Model    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission  Seats  Price  Company
# 0       CNG       Manual    5.0   1.75   Maruti
# 1    Diesel       Manual    5.0  12.50  Hyundai
# 2    Petrol       Manual    5.0   4.50    Honda
# 3    Diesel       Manual    7.0   6.00   Maruti
# 4    Diesel    Automatic    5.0  17.74     Audi

# %%
c1
# Out:
#                                  Model    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 5972                  Maruti Swift VDI       Delhi  2014              27365
# 5973          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5974             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5975                Maruti Wagon R VXI     Kolkata  2013              46000
# 5976             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission  Seats  Price    Company
# ...

# %%
c1.to_csv('Cleaned-data.csv')
